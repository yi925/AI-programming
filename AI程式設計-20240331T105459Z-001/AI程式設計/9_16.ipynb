# %% [markdown]
# ### 測試

# %% [markdown]
# # 一元二次方程式
#
# $$F(x)=3x^2+2x+1$$

# %%
print("Hello")
# Out:
# Hello

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-1, 1, 50)
y = 3*x**2 + 2*x + 1

plt.plot(x, y)

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.5
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.1
# arviz                            0.15.1
# astropy                          5.3.3
# astunparse                       1.6.3
# async-timeout                    4.0.3
# attrs                            23.1.0
# audioread                        3.0.0
# autograd                         1.6.2
# Babel                            2.12.1
# backcall                         0.2.0
# beautifulsoup4                   4.11.2
# ...

# %%
# !pip list | grep keras
# Out:
# keras                            2.13.1

# %%
# !pip install keras

# %%
import keras
print(keras._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a5035250573d> in <cell line: 2>()
#       1 import keras
# ----> 2 print(keras._version_)
#
# AttributeError: module 'keras' has no attribute '_version_'
