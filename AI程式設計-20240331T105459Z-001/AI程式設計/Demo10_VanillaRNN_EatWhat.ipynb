# %% [markdown]
# # 環境設定

# %%
# Install HappyML
import os

if not os.path.isdir("HappyML"):
    os.system("git clone https://github.com/cnchi/HappyML.git")

# %%
# Upload Dataset
Dataset_File = "Meals.csv"

if not os.path.isfile(Dataset_File):
  os.system("wget https://raw.githubusercontent.com/cnchi/datasets/master/" + Dataset_File)

# %%
sum(Dataset_File.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-51970c6c09a0> in <cell line: 1>()
# ----> 1 sum(Dataset_File.isnull().sum())
#
# AttributeError: 'str' object has no attribute 'isnull'

# %%
# Customizable Constants
train_size = 0.75

win_size = 2
sample_step = 1
win_moving = 1

data_batch = 10

# %% [markdown]
# # 資料集前處理

# %%
# Load Data
import HappyML.preprocessor as pp
import numpy as np

dataset = pp.dataset(file="Meals.csv")

# Remove the date, keep meal only
dataset = pp.onehot_encoder(dataset, columns=[1]).iloc[:, 1:]

# %%
# Keep the One Hot Encoding Mapping
mapper = [s[5:] for s in list(dataset.columns)]

# Convert dataset from DataFrame as NDArray
dataset = dataset.values
train_data, test_data = np.split(dataset, [int(train_size * len(dataset))])

# %% [markdown]
# # RNN 資料集準備

# %%
# Training Set & Testing Set for RNN
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

train_set = TimeseriesGenerator(
        data=train_data,
        targets=train_data,
        length=win_size,
        sampling_rate=sample_step,
        stride=win_moving,
        batch_size=data_batch)

test_set = TimeseriesGenerator(
        data=test_data,
        targets=test_data,
        length=win_size,
        sampling_rate=sample_step,
        stride=win_moving,
        batch_size=data_batch)

# %% [markdown]
# # 模型建造

# %%
# Create Model
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# TO-DO: Add more RNN layers & do the validation set
model = Sequential()
model.add(layers.SimpleRNN(10, input_shape=(win_size, dataset.shape[1])))
model.add(layers.Dense(dataset.shape[1], activation="softmax"))
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["acc"])

# %% [markdown]
# # 模型訓練

# %%
# Train Model
# Run multiple times of RNN can raise up the accuracy.

# TO-DO: Find the best epochs
model.fit(train_set, epochs=50)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 7s 17ms/step - loss: 1.3768 - acc: 0.3333
# Epoch 2/50
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3337 - acc: 0.3333
# Epoch 3/50
# 3/3 [==============================] - 0s 10ms/step - loss: 1.3117 - acc: 0.4762
# Epoch 4/50
# 3/3 [==============================] - 0s 10ms/step - loss: 1.2944 - acc: 0.5238
# Epoch 5/50
# 3/3 [==============================] - 0s 9ms/step - loss: 1.2771 - acc: 0.5238
# Epoch 6/50
# 3/3 [==============================] - 0s 11ms/step - loss: 1.2607 - acc: 0.5238
# Epoch 7/50
# 3/3 [==============================] - 0s 9ms/step - loss: 1.2454 - acc: 0.5238
# Epoch 8/50
# 3/3 [==============================] - 0s 10ms/step - loss: 1.2299 - acc: 0.7143
# Epoch 9/50
# 3/3 [==============================] - 0s 10ms/step - loss: 1.2170 - acc: 0.7143
# Epoch 10/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2040 - acc: 0.7143
# Epoch 11/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1894 - acc: 0.7143
# Epoch 12/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1766 - acc: 0.7143
# Epoch 13/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1648 - acc: 0.7143
# Epoch 14/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.1525 - acc: 0.7143
# Epoch 15/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1404 - acc: 0.7143
# Epoch 16/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1282 - acc: 0.7143
# Epoch 17/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1164 - acc: 0.7143
# Epoch 18/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.1049 - acc: 0.7143
# Epoch 19/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0935 - acc: 0.7143
# Epoch 20/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0832 - acc: 0.7143
# Epoch 21/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0716 - acc: 0.7143
# Epoch 22/50
# 3/3 [==============================] - 0s 7ms/step - loss: 1.0600 - acc: 0.7143
# Epoch 23/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0492 - acc: 0.7143
# Epoch 24/50
# 3/3 [==============================] - 0s 9ms/step - loss: 1.0385 - acc: 0.7143
# Epoch 25/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0280 - acc: 0.7143
# Epoch 26/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0176 - acc: 0.7143
# Epoch 27/50
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0074 - acc: 0.7143
# Epoch 28/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9972 - acc: 0.7143
# Epoch 29/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9872 - acc: 0.7143
# Epoch 30/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9771 - acc: 0.7143
# Epoch 31/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9684 - acc: 0.7143
# Epoch 32/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9572 - acc: 0.7143
# Epoch 33/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9475 - acc: 0.7143
# Epoch 34/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9393 - acc: 0.7143
# Epoch 35/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9296 - acc: 0.7143
# Epoch 36/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9199 - acc: 0.7143
# Epoch 37/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9089 - acc: 0.7143
# Epoch 38/50
# 3/3 [==============================] - 0s 13ms/step - loss: 0.9009 - acc: 0.7143
# Epoch 39/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8914 - acc: 0.7143
# Epoch 40/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8806 - acc: 0.7143
# Epoch 41/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8717 - acc: 0.7143
# Epoch 42/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8639 - acc: 0.7143
# Epoch 43/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8546 - acc: 0.7143
# Epoch 44/50
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8455 - acc: 0.7143
# Epoch 45/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8348 - acc: 0.7143
# Epoch 46/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8275 - acc: 0.7143
# Epoch 47/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8169 - acc: 0.7143
# Epoch 48/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8096 - acc: 0.7143
# Epoch 49/50
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7991 - acc: 0.7143
# Epoch 50/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7907 - acc: 0.7143

# %% [markdown]
# # 模型評估

# %%
# Model Evaluation
test_loss, test_acc = model.evaluate(test_set)
print("Loss of Test Set:", test_loss)
print("Accuracy of Test Set:", test_acc)
# Out:
# 1/1 [==============================] - 0s 250ms/step - loss: 0.8361 - acc: 0.6667
# Loss of Test Set: 0.836101770401001
# Accuracy of Test Set: 0.6666666865348816

# %% [markdown]
# # 模型預測

# %%
# Model Prediction
Y_pred = np.argmax(model.predict(test_set), axis=-1)
Y_real = np.argmax(test_set[0][1], axis=-1)

# Convert from number to label
print("Prediction:", [mapper[i] for i in Y_pred])
print("Real Value:", [mapper[i] for i in Y_real])
# Out:
# 1/1 [==============================] - 0s 166ms/step
# Prediction: ['黃金炒飯', '大魯麵', '自助餐', '黃金炒飯', '大魯麵', '黃金炒飯']
# Real Value: ['自助餐', '大魯麵', '自助餐', '黃金炒飯', '大魯麵', '煎餃']

# %% [markdown]
# # 使用者資料預測

# %%
# User input
from tensorflow.keras.utils import to_categorical

meals = []
meals += [mapper.index(input("請問你前天吃什麼："))]
meals += [mapper.index(input("請問你昨天吃什麼："))]

meals = np.reshape(to_categorical(meals, dataset.shape[1]), (1, win_size, dataset.shape[1]))
meal_today = np.argmax(model.predict(meals), axis=-1)
print("我猜你今天會吃：", mapper[meal_today[0]])
# Out:
# 請問你前天吃什麼：黃金炒飯
# 請問你昨天吃什麼：煎餃
# 1/1 [==============================] - 0s 128ms/step
# 我猜你今天會吃： 黃金炒飯
